# %%
# import seaborn and matplotlib with the standard aliases
import seaborn as sns
import matplotlib.pyplot as plt

# load the example penguins dataset
penguins = sns.load_dataset('penguins')

# create a 'regplot'
sns.regplot(x='flipper_length_mm',y='body_mass_g',data=penguins,fit_reg=True)
plt.show()

# %%
# plot the same data as above but with added lines for our 'guess'
ax = sns.regplot(x='flipper_length_mm',y='body_mass_g',data=penguins,fit_reg=True)
plt.axvline(x=190,color='red',linewidth=0.75)
plt.axhline(y=3500,color='red',linewidth=0.75)
plt.show()

# %%
# import
import pandas as pd
import numpy as np
import seaborn as sns

# load data
penguins = sns.load_dataset('penguins')

# print shape
print('Shape of the dataset (before removing NaNs): ',penguins.shape)

# drop NaNs
penguins.dropna(inplace=True)

# print shape after NaN drop
print('Shape of the dataset (after removing NaNs): ',penguins.shape)

# display head
display(penguins.head())
# Out:
# Shape of the dataset (before removing NaNs):  (344, 7)
# Shape of the dataset (after removing NaNs):  (333, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# create feature matrix
X_penguins = penguins['flipper_length_mm']
print('The shape of the feature matrix: ', X_penguins.shape)

# create the target array
y_penguins = penguins['body_mass_g']
print('The shape of the target array: ', y_penguins.shape)
# Out:
# The shape of the feature matrix:  (333,)
# The shape of the target array:  (333,)

# %%
# import the predictor class
from sklearn.linear_model import LinearRegression

# instantiate the class (with default parameters)
model = LinearRegression()

# display the model parameters
model
# Out:
# LinearRegression()

# %%
# display shape of X_penguins
print('Original features matrix: ',X_penguins.shape)

# add new axis to create a column vector
X_penguins_2D = X_penguins[:,np.newaxis]
print(X_penguins_2D.shape)
# Out:
# Original features matrix:  (333,)
# (333, 1)
# C:\Users\jeffkang\AppData\Local\Temp/ipykernel_17896/2710111533.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_penguins_2D = X_penguins[:,np.newaxis]

# %%
# fit the model
model.fit(X_penguins_2D,y_penguins)
# Out:
# LinearRegression()

# %%
# slope (also called the model coefficient)
print(model.coef_)

# intercept
print(model.intercept_)

# in equation form
print(f'\nbody_mass_g = {model.coef_[0]} x flipper_length_mm + ({model.intercept_})')
# Out:
# [50.15326594]
# -5872.092682842825
#
# body_mass_g = 50.15326594224113 x flipper_length_mm + (-5872.092682842825)

# %%
# generate the line from the model coefficients
x_line = np.linspace(170,240)
y_line = model.coef_ * x_line + model.intercept_

# %%
# import plotting libraries
import matplotlib.pyplot as plt

# create the figure and axes objects
fig, ax = plt.subplots(1)
ax.scatter(x = X_penguins, y = y_penguins, label = 'Observed data')
ax.plot(x_line, y_line, color = 'g', label = 'linear regression model')
ax.set_xlabel('Penguin flipper length (mm)')
ax.set_ylabel('Penguin weight (g)')
ax.legend()

plt.show()

# %%
# import pandas and seaborn
import pandas as pd
import numpy as np
import seaborn as sns

# load the data into a df
penguins = sns.load_dataset('penguins')

# drop NaNs
penguins.dropna(inplace=True)

# create the 2-d features matrix
X_penguins = penguins['flipper_length_mm']
X_penguins_2D = X_penguins[:,np.newaxis]

# create the target array
y_penguins = penguins['body_mass_g']
# Out:
# /var/folders/1r/07vgg77n2vd0vy3wf99ryrmh0000gn/T/ipykernel_2032/4125280038.py:14: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_penguins_2D = X_penguins[:,np.newaxis]

# %%
# import train_test_split utility
from sklearn.model_selection import train_test_split

# create the training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_penguins_2D, y_penguins, test_size=0.2,random_state=42)

print('The training and testing feature: ', X_train.shape, y_train.shape)
print('The training and testing target: ', X_test.shape, y_test.shape)
# Out:
# The training and testing feature:  (266, 1) (266,)
# The training and testing target:  (67, 1) (67,)

# %%
# import the predictor class
from sklearn.linear_model import LinearRegression

# instantiate the class
model = LinearRegression()

# fit the model
model.fit(X_train,y_train)

# slope, also called model coefficient
print(model.coef_)

# intercept
print(model.intercept_)

# print in equation form
print(f'\nbody_mass_g = {model.coef_[0]} x flipper_length_mm + ({model.intercept_})')
# Out:
# [50.41798199]
# -5919.258741821233
#
# body_mass_g = 50.41798199462178 x flipper_length_mm + (-5919.258741821233)

# %%
# use the test set for prediction
y_predict = model.predict(X_test)

# calculate the accuracy score
from sklearn.metrics import r2_score
r2_score(y_test, y_predict)
# Out:
# 0.7938115564401114

# %%
# multiple linear regression
display(penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(8,4))
sns.scatterplot(x='flipper_length_mm',y='body_mass_g',data=penguins,ax=ax1)
sns.scatterplot(x='bill_length_mm',y='body_mass_g',data=penguins,ax=ax2)
plt.show()

# %%
# remove NaN before creating features
penguins.dropna(inplace=True)

# create 2-d features matrix
features = ['flipper_length_mm', 'bill_length_mm']
X_penguins = penguins[features]

# create target array
y_penguins = penguins['body_mass_g']

# import estimator class and instantiate
model = LinearRegression()

# fit model
model.fit(X_penguins,y_penguins)

# slope (2 params)
print(model.coef_)
# intercept
print(model.intercept_)
# Out:
# [48.88969177  4.95860126]
# -5836.298732120461

# %%
# format the data for plotting
x_flipper = penguins['flipper_length_mm']
y_bill = penguins['bill_length_mm']
z_weight = penguins['body_mass_g']

# create the data to plot the best-fit plane
(x_plane, y_plane) = np.meshgrid(np.arange(165,235,1),np.arange(30,60,1))
z_plane = -5836 + 49 * x_plane + 5 * y_plane

# %%
# import for plotting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# initial the figure and axes objects
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111,projection='3d')

# plot the data: 2 features, 1 target
ax.scatter(xs=x_flipper,ys=y_bill,zs=z_weight,zdir='z',s=20,c=z_weight,cmap=cm.viridis)

# plot the best-fit plane
ax.plot_surface(x_plane,y_plane,z_plane,color='gray',alpha=0.5)

# general figure/axes properties
ax.view_init(elev=28,azim=325)
ax.set_xlabel('Flipper length')
ax.set_ylabel('Bill length')
ax.set_zlabel('Body mass')
fig.tight_layout()

plt.show()

# %%
# generate sample data
x = np.arange(25)
delta = np.random.uniform(0,20,size=(25,))
y = 0.4 * x + 3 + delta

# %%
# define a function to calc alpha and beta
def least_squares_param(x,y):
    # x and y: data to be fit, returns the least-square values of alpha and beta
    # calculate the mean of X and y
    xmean = np.mean(x); ymean = np.mean(y)
    # calculate the covariance for x and y, variance for x
    xycov = (x-xmean)*(y-ymean)
    xvar = (x-xmean)**2
    # calculate the coefficients
    beta_1 = sum(xycov) / sum(xvar)
    beta_0 = ymean - (beta_1*xmean)
    
    print('beta_0: ',beta_0)
    print('beta_1: ',beta_1)

# %%
# find the estimated parameters for alpha, beta
# given our (x,y) data set
least_squares_param(x,y)


# check

# instantiate class
model = LinearRegression()
X = x[:,np.newaxis]
# fit the model
model.fit(X,y)
# intercept
print('beta_0: ', model.intercept_)
# slope (coefficient)
print('beta_1: ', model.coef_[0])
# Out:
# beta_0:  14.689246675902853
# beta_1:  0.25419909796888013
# beta_0:  14.689246675902853
# beta_1:  0.2541990979688801
